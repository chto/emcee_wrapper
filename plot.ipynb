# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle
# %matplotlib inline

# %%
#chain = np.loadtxt("./test_chain.dat")
#chain_test = np.loadtxt("./test_chain_test.dat")
chain_continue = np.loadtxt("./test_chain_continue.dat")
chain_mpi = np.loadtxt("./test_chain_mpi.dat")

# %%
ndim=10

# %%
#for i in range(ndim):
#    plt.figure()
#    plt.hist(chain[:,i], 100, color="k", histtype="step")
#    plt.title("Dimension {0:d}".format(i))

# %%
for item in range(10):
    fig=plt.figure(figsize=(20,10))
    #plt.plot(chain[:,item],"+", label="original")
    #plt.plot(chain_test[:,item]+10,"+",alpha=1,label="no random state")
    plt.plot(chain_mpi[:,item]+10,"+",alpha=1,label="mpi")
    plt.plot(chain_continue[:,item]+20,"+",alpha=1, label="continue")
    #plt.axvline(20*100)
    plt.axvline(20*2000)
    #plt.axvline(20*300)
    plt.legend()
